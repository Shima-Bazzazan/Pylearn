# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Billionaire.csv")
data.head(10)
# Out:
#                        Name NetWorth        Country              Source  Rank  \
# 0                Jeff Bezos   $177 B  United States              Amazon     1
# 1                 Elon Musk   $151 B  United States       Tesla, SpaceX     2
# 2  Bernard Arnault & family   $150 B         France                LVMH     3
# 3                Bill Gates   $124 B  United States           Microsoft     4
# 4           Mark Zuckerberg    $97 B  United States            Facebook     5
# 5            Warren Buffett    $96 B  United States  Berkshire Hathaway     6
# 6             Larry Ellison    $93 B  United States            software     7
# 7                Larry Page  $91.5 B  United States              Google     8
# 8               Sergey Brin    $89 B  United States              Google     9
# 9             Mukesh Ambani  $84.5 B          India         diversified    10
#
#     Age               Industry
# 0  57.0             Technology
# 1  49.0             Automotive
# 2  72.0       Fashion & Retail
# 3  65.0             Technology
# 4  36.0             Technology
# 5  90.0  Finance & Investments
# 6  76.0             Technology
# 7  48.0             Technology
# 8  47.0             Technology
# 9  63.0            Diversified

# %%
data.isnull().sum()
# Out:
# Name         0
# NetWorth     0
# Country      0
# Source       0
# Rank         0
# Age         79
# Industry     0
# dtype: int64

# %%
data = data.dropna()
data.isnull().sum()
# Out:
# Name        0
# NetWorth    0
# Country     0
# Source      0
# Rank        0
# Age         0
# Industry    0
# dtype: int64

# %%
data["NetWorth"] = data["NetWorth"].str.strip("$")
data["NetWorth"] = data["NetWorth"].str.strip("B")
data["NetWorth"] = data["NetWorth"].astype(float)

# %%
data.head()
# Out:
#                        Name  NetWorth        Country         Source  Rank  \
# 0                Jeff Bezos     177.0  United States         Amazon     1
# 1                 Elon Musk     151.0  United States  Tesla, SpaceX     2
# 2  Bernard Arnault & family     150.0         France           LVMH     3
# 3                Bill Gates     124.0  United States      Microsoft     4
# 4           Mark Zuckerberg      97.0  United States       Facebook     5
#
#     Age          Industry
# 0  57.0        Technology
# 1  49.0        Automotive
# 2  72.0  Fashion & Retail
# 3  65.0        Technology
# 4  36.0        Technology

# %%
df = data.sort_values(by=["NetWorth"], ascending=False).head(10).reset_index()
df
# Out:
#    index                      Name  NetWorth        Country  \
# 0      0                Jeff Bezos     177.0  United States
# 1      1                 Elon Musk     151.0  United States
# 2      2  Bernard Arnault & family     150.0         France
# 3      3                Bill Gates     124.0  United States
# 4      4           Mark Zuckerberg      97.0  United States
# 5      5            Warren Buffett      96.0  United States
# 6      6             Larry Ellison      93.0  United States
# 7      7                Larry Page      91.5  United States
# 8      8               Sergey Brin      89.0  United States
# 9      9             Mukesh Ambani      84.5          India
#
#                Source  Rank   Age               Industry
# 0              Amazon     1  57.0             Technology
# 1       Tesla, SpaceX     2  49.0             Automotive
# 2                LVMH     3  72.0       Fashion & Retail
# 3           Microsoft     4  65.0             Technology
# 4            Facebook     5  36.0             Technology
# 5  Berkshire Hathaway     6  90.0  Finance & Investments
# 6            software     7  76.0             Technology
# 7              Google     8  48.0             Technology
# 8              Google     9  47.0             Technology
# 9         diversified    10  63.0            Diversified

# %%
plt.figure(figsize=(24, 8))
plt.bar(df["Name"], df["NetWorth"])
plt.show()

# %%
df = data["Source"].value_counts().head(10).reset_index()
df
# Out:
#             Source  count
# 0      real estate    169
# 1  pharmaceuticals     96
# 2      investments     89
# 3      diversified     78
# 4         software     61
# 5           retail     44
# 6      hedge funds     42
# 7   private equity     35
# 8   consumer goods     32
# 9        chemicals     32

# %%
plt.pie(df["count"], labels=df["Source"])
plt.title("Top 10 Career Fields That Produce the Most Billionaires")
plt.show()

# %%
df = data["Industry"].value_counts().reset_index()
df
# Out:
#                       Industry  count
# 0        Finance & Investments    365
# 1                   Technology    355
# 2                Manufacturing    317
# 3             Fashion & Retail    268
# 4                   Healthcare    213
# 5                  Real Estate    211
# 6              Food & Beverage    204
# 7                  Diversified    180
# 8                       Energy     99
# 9        Media & Entertainment     92
# 10                     Service     73
# 11             Metals & Mining     73
# 12                  Automotive     67
# 13  Construction & Engineering     43
# 14                   Logistics     35
# 15                     Telecom     32
# 16          Gambling & Casinos     25
# 17                      Sports     24

# %%
plt.figure(figsize=(8, 8))
plt.pie(df["count"], labels=df["Industry"])
plt.title("Industries in which billionaires are active")
plt.show()

# %%
df = data["Country"].value_counts().head().reset_index()
df
# Out:
#          Country  count
# 0  United States    720
# 1          China    610
# 2          India    134
# 3         Russia    118
# 4        Germany    115

# %%
plt.figure(figsize=(6, 6))
plt.pie(df["count"], labels=df["Country"])
plt.title("Countries with the most billionaires")
plt.show()

# %%
data.head()
# Out:
#                        Name  NetWorth        Country         Source  Rank  \
# 0                Jeff Bezos     177.0  United States         Amazon     1
# 1                 Elon Musk     151.0  United States  Tesla, SpaceX     2
# 2  Bernard Arnault & family     150.0         France           LVMH     3
# 3                Bill Gates     124.0  United States      Microsoft     4
# 4           Mark Zuckerberg      97.0  United States       Facebook     5
#
#     Age          Industry
# 0  57.0        Technology
# 1  49.0        Automotive
# 2  72.0  Fashion & Retail
# 3  65.0        Technology
# 4  36.0        Technology

# %%
df = data[["Name", "Age"]]
df
# Out:
#                           Name   Age
# 0                   Jeff Bezos  57.0
# 1                    Elon Musk  49.0
# 2     Bernard Arnault & family  72.0
# 3                   Bill Gates  65.0
# 4              Mark Zuckerberg  36.0
# ...                        ...   ...
# 2750         Daniel Yong Zhang  49.0
# 2751             Zhang Yuqiang  65.0
# 2752             Zhao Meiguang  58.0
# 2753            Zhong Naixiong  58.0
# 2754           Zhou Wei family  54.0
#
# [2676 rows x 2 columns]

# %%
df = data["Age"].mean()
df
# Out:
# np.float64(63.1136023916293)

# %%
df = data["Age"].var()
df
# Out:
# np.float64(180.7721364011008)

# %%
df = data.groupby("Country")["NetWorth"].sum().reset_index()
df = df.sort_values(by=['NetWorth'], ascending=False)
df.head(10)
# Out:
#           Country  NetWorth
# 66  United States    4384.7
# 8           China    2496.1
# 50         Russia     586.0
# 18        Germany     576.6
# 24          India     567.3
# 16         France     507.6
# 21      Hong Kong     428.4
# 29          Japan     222.2
# 6          Canada     217.5
# 5          Brazil     200.7

# %%
plt.figure(figsize=(24, 8))
plt.bar(df["Country"], df["NetWorth"])
plt.xticks(rotation=90)
plt.xlabel("country")
plt.ylabel("wealth ($B)")
plt.title("Total wealth of billionaires of each country")
plt.savefig("output/1.jpg")
plt.show()

# %%
df=data.query('Country=="United States" ').reset_index()
df
# Out:
#      index                   Name  NetWorth        Country  \
# 0        0             Jeff Bezos     177.0  United States
# 1        1              Elon Musk     151.0  United States
# 2        3             Bill Gates     124.0  United States
# 3        4        Mark Zuckerberg      97.0  United States
# 4        5         Warren Buffett      96.0  United States
# ..     ...                    ...       ...            ...
# 715   2732             Vlad Tenev       1.0  United States
# 716   2739  Vlad Vendrow & family       1.0  United States
# 717   2742        J. Wayne Weaver       1.0  United States
# 718   2743            Sandy Weill       1.0  United States
# 719   2749             Yu De-Chao       1.0  United States
#
#                  Source  Rank   Age               Industry
# 0                Amazon     1  57.0             Technology
# 1         Tesla, SpaceX     2  49.0             Automotive
# 2             Microsoft     4  65.0             Technology
# 3              Facebook     5  36.0             Technology
# 4    Berkshire Hathaway     6  90.0  Finance & Investments
# ..                  ...   ...   ...                    ...
# 715       stock trading  2674  34.0  Finance & Investments
# 716            software  2674  53.0             Technology
# 717               Shoes  2674  85.0            Diversified
# 718           Citigroup  2674  88.0  Finance & Investments
# 719     pharmaceuticals  2674  57.0             Healthcare
#
# [720 rows x 8 columns]

# %%
df=df.sort_values(by=["NetWorth"],ascending=False).head(10).reset_index()
df
# Out:
#    level_0  index             Name  NetWorth        Country  \
# 0        0      0       Jeff Bezos     177.0  United States
# 1        1      1        Elon Musk     151.0  United States
# 2        2      3       Bill Gates     124.0  United States
# 3        3      4  Mark Zuckerberg      97.0  United States
# 4        4      5   Warren Buffett      96.0  United States
# 5        5      6    Larry Ellison      93.0  United States
# 6        6      7       Larry Page      91.5  United States
# 7        7      8      Sergey Brin      89.0  United States
# 8        8     13    Steve Ballmer      68.7  United States
# 9        9     16     Alice Walton      61.8  United States
#
#                Source  Rank   Age               Industry
# 0              Amazon     1  57.0             Technology
# 1       Tesla, SpaceX     2  49.0             Automotive
# 2           Microsoft     4  65.0             Technology
# 3            Facebook     5  36.0             Technology
# 4  Berkshire Hathaway     6  90.0  Finance & Investments
# 5            software     7  76.0             Technology
# 6              Google     8  48.0             Technology
# 7              Google     9  47.0             Technology
# 8           Microsoft    14  65.0             Technology
# 9             Walmart    17  71.0       Fashion & Retail

# %%
plt.figure(figsize=(12, 8))
plt.bar(df["Name"], df["NetWorth"])
plt.xticks(rotation=45)
plt.xlabel("name")
plt.ylabel("wealth ($B)")
plt.title("Top 10 billionaires of US")
plt.savefig("output/2.jpg")
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.pie(df["NetWorth"], labels=df["Name"])
plt.title("Top 10 billionaires of US")
plt.savefig("output/3.jpg")
plt.show()

# %%
df = data["Country"].value_counts().tail(10).reset_index()
df
# Out:
#                 Country  count
# 0         Liechtenstein      1
# 1             Venezuela      1
# 2  United Arab Emirates      1
# 3                  Oman      1
# 4                 Macao      1
# 5              Guernsey      1
# 6              Tanzania      1
# 7   St. Kitts and Nevis      1
# 8              Zimbabwe      1
# 9                 Nepal      1

# %%
plt.figure(figsize=(12, 8))
plt.bar(df["Country"], df["count"])
plt.xticks(rotation=45)
plt.xlabel("country")
plt.ylabel("number of billionaires")
plt.title("10 countries with least number of billionaires")
plt.savefig("output/4.jpg")
plt.show()
